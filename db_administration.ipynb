# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
Base = automap_base()
engine = create_engine("sqlite:///chi_db.sqlite")

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['Community Names', 'community_names']

# %%
engine.execute('SELECT * FROM community_names;').fetchall()
# Out:
# [(1, 'Rogers Park'),
#  (2, 'West Ridge'),
#  (3, 'Uptown'),
#  (4, 'Lincoln Square'),
#  (5, 'North Center'),
#  (6, 'Lake View'),
#  (7, 'Lincoln Park'),
#  (8, 'Near North Side'),
#  (9, 'Edison Park'),
#  (10, 'Norwood Park'),
#  (11, 'Jefferson Park'),
#  (12, 'Forest Glen'),
#  (13, 'North Park'),
#  (14, 'Albany Park'),
#  (15, 'Portage Park'),
#  (16, 'Irving Park'),
#  (17, 'Dunning'),
#  (18, 'Montclare'),
#  (19, 'Belmont Cragin'),
#  (20, 'Hermosa'),
#  (21, 'Avondale'),
#  (22, 'Logan Square'),
#  (23, 'Humboldt Park'),
#  (24, 'West Town'),
#  (25, 'Austin'),
#  (26, 'West Garfield Park'),
#  (27, 'East Garfield Park'),
#  (28, 'Near West Side'),
#  (29, 'North Lawndale'),
#  (30, 'South Lawndale'),
#  (31, 'Lower West Side'),
#  (32, 'Loop'),
#  (33, 'Near South Side'),
#  (34, 'Armour Square'),
#  (35, 'Douglas'),
#  (36, 'Oakland'),
#  (37, 'Fuller Park'),
#  (38, 'Grand Boulevard'),
#  (39, 'Kenwood'),
#  (40, 'Washington Park'),
#  (41, 'Hyde Park'),
# ...

# %%
names.to_sql(name='community_names', con=engine, if_exists='replace',index=True)
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-42-43f85f469859> in <module>()
#       1
# ...

# %%
inspector.get_columns('Community_Names')
# Out:
# [{'autoincrement': 'auto',
#   'default': None,
#   'name': 'ID',
#   'nullable': True,
#   'primary_key': 0,
#   'type': BIGINT()},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Community',
#   'nullable': True,
#   'primary_key': 0,
#   'type': TEXT()}]

# %%
engine.execute('SELECT Community_Names.Community, Pop_History.1930 FROM Community_Names JOIN POP_History ON Community_Names.ID = Pop_History.ID;').fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: near ".1930": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-44-99f7caa5d89b> in <module>()
# ...
