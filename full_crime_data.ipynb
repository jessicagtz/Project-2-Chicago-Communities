# %%
import pandas as pd
import numpy as np

# %%
crimes = pd.read_csv("Crimes_-_2001_to_present.csv").fillna(0)
crimes.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
crimes = crimes.drop(crimes[crimes['Community Area'] == 0].index)
crimes.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
crimes.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
crimes["Community Area"].astype(np.int64)
# Out:
# 0          25
# 1          67
# 2          39
# 3          40
# 4          25
# 5          39
# 6          68
# 7          38
# 8          59
# 9          49
# 10         54
# 11         69
# 12         46
# 13         28
# 14         25
# 15         43
# 16         24
# 17         67
# 18         49
# 19         48
# 20         43
# 21         32
# 22         77
# 23         43
# 24         25
# 25         31
# 26         40
# 27         73
# 28         71
# 29         71
#            ..
# 6609798    41
# 6609799    49
# 6609800    53
# 6609801     2
# 6609802     6
# 6609803    21
# 6609804    44
# 6609805    44
# 6609806    35
# 6609807    33
# 6609808    71
# 6609809    41
# 6609810    53
# 6609811    75
# 6609812     1
# 6609813    29
# 6609814     8
# 6609815    21
# 6609816    35
# 6609817     8
# 6609818    38
# 6609819    41
# 6609820    32
# 6609821     7
# 6609822    27
# 6609823    71
# 6609824    76
# 6609825    29
# 6609826    25
# 6609827    29
# ...

# %%
crime_org= pd.DataFrame(crimes.pivot_table(crimes,index=["Community Area", "Primary Type"]))
crime_org.head()
# Out:
#                                       Arrest         Beat   District  \
# Community Area Primary Type
# 1.0            ARSON                0.218391  2425.977011  24.000000
#                ASSAULT              0.281756  2426.092617  24.000000
#                BATTERY              0.250044  2426.003945  23.998705
#                BURGLARY             0.061703  2426.605718  24.000000
#                CRIM SEXUAL ASSAULT  0.166265  2426.315663  24.000000
#
#                                     Domestic            ID   Latitude  \
# Community Area Primary Type
# 1.0            ARSON                0.022989  5.660522e+06  42.011640
#                ASSAULT              0.152873  6.684783e+06  41.871147
#                BATTERY              0.361966  6.473039e+06  41.828879
#                BURGLARY             0.002468  6.049225e+06  41.898046
#                CRIM SEXUAL ASSAULT  0.098795  7.135471e+06  40.189210
#
# ...

# %% [markdown]
# # Reported Crimes - Community Area by type per year

# %%
crime_data = pd.DataFrame(crimes.pivot_table(values=["ID"], index=["Community Area", "Primary Type", "Year"], aggfunc=np.sum))
crime_data
# Out:
#                                                ID
# Community Area Primary Type      Year
# 1.0            ARSON             2002    16293172
#                                  2003    31325781
#                                  2004    50270173
#                                  2005    20463097
#                                  2006    49126336
#                                  2007    17107498
#                                  2008    12707744
#                                  2009    20622116
#                                  2010    45612126
#                                  2011    57127478
#                                  2012    43451954
#                                  2013    45960408
#                                  2014     9777048
#                                  2015    40685409
#                                  2016    20936898
#                                  2017    10998141
#                ASSAULT           2002   757069187
# ...

# %%
crime_data.to_csv("organized_crime_data.csv")

# %% [markdown]
# # Number of Reported Crimes per Commuity Area

# %%
#1) group by community area
#2) get numbers of crime type per community area

crime_area= pd.DataFrame(crimes.groupby("Community Area")["ID"].count())
crime_area.head()
# Out:
#                    ID
# Community Area
# 1.0             91970
# 2.0             74711
# 3.0             87919
# 4.0             41995
# 5.0             36176

# %% [markdown]
# # Number of Reported Crimes per Primary Type from 2001-2018

# %%
crime_type= pd.DataFrame(crimes.groupby("Primary Type")["ID"].count())
crime_type.sort_values(by= "ID", ascending= False)
# Out:
#                                         ID
# Primary Type
# THEFT                              1260924
# BATTERY                            1087821
# CRIMINAL DAMAGE                     685380
# NARCOTICS                           636960
# OTHER OFFENSE                       370469
# ASSAULT                             368126
# BURGLARY                            349284
# MOTOR VEHICLE THEFT                 276474
# DECEPTIVE PRACTICE                  234583
# ROBBERY                             227491
# CRIMINAL TRESPASS                   172509
# WEAPONS VIOLATION                    62181
# PROSTITUTION                         59929
# PUBLIC PEACE VIOLATION               43665
# OFFENSE INVOLVING CHILDREN           41564
# CRIM SEXUAL ASSAULT                  24065
# SEX OFFENSE                          21867
# INTERFERENCE WITH PUBLIC OFFICER     13964
# GAMBLING                             13138
# LIQUOR LAW VIOLATION                 11891
# ...
